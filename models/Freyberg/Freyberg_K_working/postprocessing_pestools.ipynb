# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pestools
import pyemu
# Out:
# setting random seed

# %%
res=pestools.Res('../freyberg_pilotpoints/freyberg_pp.rei')

# %%
res.plot_one2one('head_cal', figsize=(5,5))
# Out:
# (<matplotlib.figure.Figure at 0x10846fa20>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12148aa20>)

# %%
res.plot_measured_vs_residual('head_cal')

# %%
res.print_stats('head_cal')
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Observation Group: head_cal
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Number of observations in group: 13
# -------Measured Stats------------------
# Minimum:   1.4736e+01  Maximum:   3.1834e+01
# Range:     1.7098e+01
# -------Residual Stats------------------
# Mean:      2.0315e+00  Std Dev:    1.8507e+00
# Minimum:   -5.1489e-01  Maximum:    5.1254e+00
# RMSE:      2.7481e+00  RMSE/Range: 1.6073e-01
# Range:     5.6403e+00
# -------Absolute Residual Stats---------
# Mean:      2.1631e+00  Std Dev:   1.6951e+00
# Minimum:   5.4000e-04  Maximum:   5.1254e+00
# Range:     5.1248e+00
# -------Weighted Residual Stats---------
# Mean:      2.0315e+00  Std Dev:   1.8507e+00
# Minimum:   -5.1489e-01  Maximum:   5.1254e+00
# Range:     5.6403e+00

# %%
res.objective_contrib()
# Out:
# 0.00%   flux_fore
# 0.00%   head_fore
# 0.00%   travel_fore
# 0.00%   head_cal
# 100.00%   flux_cal

# %%
res.df
# Out:
#                       Name        Group      Measured     Modelled  \
# cr03c16            cr03c16     head_cal      22.18672     19.52004
# cr03c10            cr03c10     head_cal      24.08591     21.43116
# cr04c9              cr04c9     head_cal      22.33339     21.76925
# cr10c2              cr10c2     head_cal      31.83430     26.70893
# cr14c11            cr14c11     head_cal      17.72841     17.72895
# cr16c17            cr16c17     head_cal      16.56648     17.08137
# cr22c11            cr22c11     head_cal      18.28594     16.56486
# cr23c16            cr23c16     head_cal      15.20820     15.54790
# cr25c5              cr25c5     head_cal      24.24294     19.70467
# cr27c7              cr27c7     head_cal      22.74890     18.04035
# cr30c16            cr30c16     head_cal      14.73617     13.99087
# cr34c8              cr34c8     head_cal      18.61989     15.87012
# cr35c11            cr35c11     head_cal      15.61996     13.82886
# ...

# %%
res.plot_objective_contrib();

# %%
res.plot_measure_vs_model('head_cal')

# %%
ip = pestools.IdentPar('../freyberg_pilotpoints/freyberg_pp.jcb')

# %%
fig, ax = ip.plot_bar(nsingular=50, nbars=40)

# %%
injac = pyemu.Jco.from_binary(os.path.join('..','Freyberg_pilotpoints','freyberg_pp.jcb'))

# %%
sens = pestools.ParSen(basename=os.path.join('..','Freyberg_pilotpoints','freyberg_pp.jcb'),
                       jco_df=injac.df(), res_df = res.df.copy())

# %%
sens.plot()
# Out:
# (<matplotlib.figure.Figure at 0x12542fe48>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12567f390>)

# %%
sens.plot_mean_group()
# Out:
# (<matplotlib.figure.Figure at 0x125b0ec18>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x125fdfc88>)

# %%
sens.sum_group()
# Out:
#                  Sensitivity
# Parameter Group
# rch                 7.361936
# pilotpt             2.864529

# %%
sens
