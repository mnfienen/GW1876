# %% [markdown]
# # Setup the PEST(++) interface around the enhanced Freyberg model

# %% [markdown]
# In this notebook, we will construct a complex model independent (non-intrusive) interface around an existing `MODFLOW-NWT` model using the `python/flopy/pyemu` stack.

# %%
# %matplotlib inline
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import flopy
import pyemu
import prep_deps
import redis
import matplotlib as mpl
plt.rcParams['font.size']=12
# %matplotlib inline
pyemu.__path__
# Out:
# flopy is installed in /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/flopy
# ['/Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu']

# %% [markdown]
# First we define a base directory `b_d` from which we will read in a model already created `freyberg.nam`. This will form the basis of the remainder of the exercise (and those to follow)

# %%
os.getcwd()
# Out:
# '/Users/jwhite/Dev/gw1876/activities_stpete/notebooks'

# %%
b_d = os.path.join("temp_history")
nam_file = "freyberg.nam"
assert os.path.exists(b_d),"you need to run the setup_transient_history notebook"

# %% [markdown]
# ### load the existing Freyberg model. This version should run but is not yet connected with `PEST++`

# %%
# note that to load a model in a different folder, you supply the namefile without path and supply the path
# to it in the model_ws variable
m = flopy.modflow.Modflow.load(nam_file,model_ws=b_d,check=False,forgive=False)

# %% [markdown]
# ### some visuals

# %%
# plot some model attributes
fig = plt.figure(figsize=(12,7))
ax = plt.subplot(111,aspect="equal")
mm = flopy.plot.PlotMapView(model=m)
mm.plot_grid()
mm.plot_ibound()
mm.plot_bc('SFR')
mm.plot_bc("GHB")
ax = mm.ax
#m.wel.stress_period_data.plot(ax=ax,mflay=2)

# plot obs locations
obs = pd.read_csv(os.path.join("..","base_model_files","obs_loc.csv"))
                  
obs_x = [m.sr.xcentergrid[r-1,c-1] for r,c in obs.loc[:,["row","col"]].values]
obs_y = [m.sr.ycentergrid[r-1,c-1] for r,c in obs.loc[:,["row","col"]].values]
ax.scatter(obs_x,obs_y,marker='.',label="water-level obs",s=80)

#plot names on the pumping well locations
wel_data = m.wel.stress_period_data[0]
wel_x = m.sr.xcentergrid[wel_data["i"],wel_data["j"]]
wel_y = m.sr.ycentergrid[wel_data["i"],wel_data["j"]]
for i,(x,y) in enumerate(zip(wel_x,wel_y)):
    ax.scatter([x],[y],color="red",marker="s",s=50)
    #ax.text(x,y,"{0}".format(i+1),ha="center",va="center")

ax.set_ylabel("y(m)")
ax.set_xlabel("x(m)")
plt.show()

# %% [markdown]
# ### we can do a couple `flopy` things to move where the new model will be written

# %%
# assign the executable name for the model
m.exe_name = "mfnwt"

# now let's run this in a new folder called temp so we don't overwrite the original data
m.change_model_ws("temp",reset_external=True)

# this writes all the MODFLOW files in the new location 
m.write_input()

# the following helps get the dependecies (both python and executables) in the right place
prep_deps.prep_template(t_d="temp")
# Out:
# changing model workspace...
#    temp

# %% [markdown]
# ### now we can run the model once using a `pyemu` helper
# This helper is particularly useful if you run on more than one platform (e.g. Mac and Windows)

# %%
pyemu.os_utils.run("{0} {1}".format(m.exe_name,m.name+".nam"),cwd=m.model_ws)

# %% [markdown]
# ### read in the heads and plot them up along with the budget components
# Note that there is a historic period and a scenario with future conditions that differ.
#
# _For the future scenario, a serious drought, recharge is lower and pumping/abstraction is increased to make up for the presumed deficite in water for agriculture._

# %%
plt.rcParams['font.size']=12
plt.figure()
hds = flopy.utils.HeadFile(os.path.join(m.model_ws,m.name+".hds"),model=m)
hds.plot(mflay=0)
lst = flopy.utils.MfListBudget(os.path.join(m.model_ws,m.name+".list"))
df = lst.get_dataframes(diff=True)[0]
plt.figure()
ax = df.plot(kind="bar",figsize=(30,30), grid=True,subplots=True)

# %% [markdown]
# ### Plot depth to water

# %%
dtw = m.dis.top.array - hds.get_data()[0,:,:]
dtw = np.ma.masked_where(m.bas6.ibound[0].array==0,dtw)
c = plt.imshow(dtw)
plt.title('Depth to Water')
plt.colorbar(c)

# %% [markdown]
# we can see the river and well locations expressed in the depth to water pattern.

# %% [markdown]
# ## Setup data structures related to what we want to parameterize and what we want to observe

# %% [markdown]
# ## First the parameterization of model inputs. There is a method to the madness. Starting with MODFLOW parameters that are array-style

# %% [markdown]
# we can use package/parameter definitions with strings like `'pak.prop'` where `pak` is the abbreviation for a MODFLOW package as interpreted by `flopy` and `prop` is the short abbrevation for a property in the package. For example, `'upw.ss.'` is the specific storage in the Upstream Weighting Package.
#
# For parameters that vary by layer but not by time, we also need to specify which layer (zero-indexed....it's python y'all!) to apply to. So, specify the package/layer combo in a little list like:
#  `['upw.hk', 0]` for `hk` in the `upw` package in layer 0
#
# For parameters that vary by time but not by layer (basically talking recharge here), similar logic is used, except the counter indicates the stress period (still zero-based. still python) like:
# `['rch.rech',1]`  is recharge in stress period 1
# There is a shortcut for the numbering if you want to specify for all stress periods or all layers (as appropriate). Note that this will apply one set of parameters across layers or stress periods...it will not make distinct parameters for each. Rather than specifying a number, you use the variable `None` like:
# `['rch.rech',None]` for recharge across all stress periods or `['upw.ss',None]` for specific storage across all layers

# %% [markdown]
# So we are going to do this for a variety of packages/properties in two lists. One `props` will be for packages we want to apply distributed parameters to (e.g. pilot points and grid-based parameters). Then we will add another `constant_props` which will include stress-period based recharge multipliers as well. These will add together as we will see later

# %%
props = []
# here we specify which packages we wish to parameterize, 
# starting with those that do not change over time
paks = ["upw.hk","upw.vka","upw.ss","upw.sy","extra.prsity"]  #"extra" because not a modflow parameter
for k in range(m.nlay):
    props.extend([[p,k] for p in paks])
const_props = props.copy()
props.append(["rch.rech",None])
for kper in range(m.nper):
    const_props.append(["rch.rech",kper])
print('props')
props
# Out:
# props
# [['upw.hk', 0],
#  ['upw.vka', 0],
#  ['upw.ss', 0],
#  ['upw.sy', 0],
#  ['extra.prsity', 0],
#  ['upw.hk', 1],
#  ['upw.vka', 1],
#  ['upw.ss', 1],
#  ['upw.sy', 1],
#  ['extra.prsity', 1],
#  ['upw.hk', 2],
#  ['upw.vka', 2],
#  ['upw.ss', 2],
#  ['upw.sy', 2],
#  ['extra.prsity', 2],
#  ['rch.rech', None]]

# %%
print('const_props')
const_props
# Out:
# const_props
# [['upw.hk', 0],
#  ['upw.vka', 0],
#  ['upw.ss', 0],
#  ['upw.sy', 0],
#  ['extra.prsity', 0],
#  ['upw.hk', 1],
#  ['upw.vka', 1],
#  ['upw.ss', 1],
#  ['upw.sy', 1],
#  ['extra.prsity', 1],
#  ['upw.hk', 2],
#  ['upw.vka', 2],
#  ['upw.ss', 2],
#  ['upw.sy', 2],
#  ['extra.prsity', 2],
#  ['rch.rech', 0],
#  ['rch.rech', 1],
#  ['rch.rech', 2],
#  ['rch.rech', 3],
#  ['rch.rech', 4],
#  ['rch.rech', 5],
#  ['rch.rech', 6],
#  ['rch.rech', 7],
#  ['rch.rech', 8],
#  ['rch.rech', 9],
#  ['rch.rech', 10],
#  ['rch.rech', 11],
#  ['rch.rech', 12],
#  ['rch.rech', 13],
#  ['rch.rech', 14],
#  ['rch.rech', 15],
#  ['rch.rech', 16],
#  ['rch.rech', 17],
#  ['rch.rech', 18],
#  ['rch.rech', 19],
#  ['rch.rech', 20],
#  ['rch.rech', 21],
#  ['rch.rech', 22],
#  ['rch.rech', 23],
#  ['rch.rech', 24]]

# %% [markdown]
# ## Now we can handle MDOFLOW list-style parameters in two ways
# for `spatial_list_props` this will apply a multiplier distributed spatially that applied in all stress periods throughout the model
#
# for `temporal_list_props` this will apply a multiplier for each stress period applied to all the spatial locations

# %%
spatial_list_props = [["wel.flux",2],["ghb.cond",0],["ghb.cond",1],["ghb.cond",2]]  # spatially by each list entry, across all stress periods
temporal_list_props = [["wel.flux",kper] for kper in range(m.nper)]  # spatially uniform for each stress period
print(spatial_list_props)
temporal_list_props
# Out:
# [['wel.flux', 2], ['ghb.cond', 0], ['ghb.cond', 1], ['ghb.cond', 2]]
# [['wel.flux', 0],
#  ['wel.flux', 1],
#  ['wel.flux', 2],
#  ['wel.flux', 3],
#  ['wel.flux', 4],
#  ['wel.flux', 5],
#  ['wel.flux', 6],
#  ['wel.flux', 7],
#  ['wel.flux', 8],
#  ['wel.flux', 9],
#  ['wel.flux', 10],
#  ['wel.flux', 11],
#  ['wel.flux', 12],
#  ['wel.flux', 13],
#  ['wel.flux', 14],
#  ['wel.flux', 15],
#  ['wel.flux', 16],
#  ['wel.flux', 17],
#  ['wel.flux', 18],
#  ['wel.flux', 19],
#  ['wel.flux', 20],
#  ['wel.flux', 21],
#  ['wel.flux', 22],
#  ['wel.flux', 23],
#  ['wel.flux', 24]]

# %% [markdown]
# ## Now for model outputs

# %% [markdown]
# next we want to set up the extraction of model outputs that are of interest, not just places where we have state observations. In many cases we are interested in dry conditions and also the last stress period.  So lets include simulated water levels from a dry stress period and from the last stress period.  The container `hds_kperk` is a nested list of stress period and layer pairs from which we want to `observe` (in the PEST control file sense) the simulated water levels from (all active cells are included)

# %%
dry_kper = int(m.nper * 0.85) # the "dry" season in the last annual cycle
hds_kperk = [[kper,k] for k in range(m.nlay) for kper in [0,dry_kper,m.nper-1]]
#hds_kperk.extend([[1,k] for k in range(m.nlay)])
hds_kperk
# Out:
# [[0, 0], [21, 0], [24, 0], [0, 1], [21, 1], [24, 1], [0, 2], [21, 2], [24, 2]]

# %% [markdown]
# ### then we setup monitoring of the SFR ASCII outputs.
# we will accumulate the first 20 reaches and last 20 reaches (corresponding to the top and bottom half of the model, respectively) together to form forecasts of sw-gw exchange in the headwaters (`hw`) and tailwaters (`tw`).  We will also include the most downstream reach since that is where we have surface-water flow state observations for history matching.  The container `sft_obs_dict` will help us setup PEST `observations`.  Then later we will have to assign actual observation data to these quantities.

# %%
sfr_obs_dict = {}
sfr_obs_dict["hw"] = np.arange(1,int(m.nrow/2))
sfr_obs_dict["tw"] = np.arange(int(m.nrow/2),m.nrow)
sfr_obs_dict["gage_1"] = [39]
#for i in range(m.nrow):
#    sfr_obs_dict[i] = i+1

# %% [markdown]
# ### here we go...
#
# This `pyemu` class has grown into a monster...it does (among other things):
# - sets up combinations of multiplier parameters for array inputs, including uniform, zones, pilot points, grids, and KL expansion types
# - sets up combinations of multiplier parameters for list inputs
# - handles several of the shitty modflow exceptions to the array and list style inputs
# - sets up large numbers of observations based on arrays or time series
# - writes .tpl, .ins, .pst, etc
# - writes a python forward run script
# - writes a prior parameter covaraince matrix using geostatistical correlations
# - draws from the prior parameter covariance matrix to generate a prior parameter ensemble
#
# WAT?!
#
# This will be slow because the pure python kriging...but, hey, its free!
#
# For our purposes, we will setup combinations of constant (by layer), pilot points and grid-scale parameters for each of the array-based properties we defined earlier.  This lets us explore options for parameterization and also start to understand how information flows in the history matching problem

# %%
pst_helper = pyemu.helpers.PstFromFlopyModel(nam_file,new_model_ws="template_history",org_model_ws="temp",
                                             const_props=const_props,
                                             spatial_list_props=spatial_list_props,
                                             temporal_list_props=temporal_list_props,
                                             remove_existing=True,
                                             pp_props=props,
                                             grid_props=props,
                                             sfr_pars=["strk"],
                                             hds_kperk=hds_kperk,
                                             sfr_obs=sfr_obs_dict,
                                             build_prior=False,
                                             model_exe_name="mfnwt",
                                             pp_space=4)
prep_deps.prep_template(t_d=pst_helper.new_model_ws)
# Out:
# 2020-03-06 08:40:46.142797 starting: loading flopy model
#
# Creating new model with name: freyberg
# --------------------------------------------------
#
# Parsing the namefile --> temp/freyberg.nam
#
# --------------------------------------------------
# External unit dictionary:
# {2: filename:temp/freyberg.list, filetype:LIST, 11: filename:temp/freyberg.dis, filetype:DIS, 13: filename:temp/freyberg.bas, filetype:BAS6, 31: filename:temp/freyberg.upw, filetype:UPW, 32: filename:temp/freyberg.nwt, filetype:NWT, 14: filename:temp/freyberg.oc, filetype:OC, 20: filename:temp/freyberg.wel, filetype:WEL, 19: filename:temp/freyberg.rch, filetype:RCH, 23: filename:temp/freyberg.ghb, filetype:GHB, 17: filename:temp/freyberg.sfr, filetype:SFR, 50: filename:temp/freyberg.cbc, filetype:DATA(BINARY), 51: filename:temp/freyberg.hds, filetype:DATA(BINARY), 60: filename:temp/freyberg.sfr.out, filetype:DATA}
# --------------------------------------------------
#
# ModflowBas6 free format:True
#
# loading dis package file...
#    Loading dis package with:
#       3 layers, 40 rows, 20 columns, and 25 stress periods
#    loading laycbd...
#    loading delr...
#    loading delc...
#    loading top...
#    loading botm...
#       for 3 layers and 0 confining beds
#    loading stress period data...
#        for 25 stress periods
# adding Package:  DIS
#    DIS  package load...success
#    LIST package load...skipped
# loading bas6 package file...
# adding Package:  BAS6
#    BAS6 package load...success
# loading upw package file...
#    loading ipakcb, HDRY, NPUPW, IPHDRY...
#    loading LAYTYP...
#    loading LAYAVG...
#    loading CHANI...
#    loading LAYVKA...
#    loading LAYWET...
#    loading hk layer   1...
#    loading vka layer   1...
#    loading ss layer   1...
#    loading sy layer   1...
#    loading hk layer   2...
#    loading vka layer   2...
#    loading ss layer   2...
#    loading hk layer   3...
#    loading vka layer   3...
#    loading ss layer   3...
# Adding freyberg.cbc (unit=50) to the output list.
# adding Package:  UPW
#    UPW  package load...success
# loading nwt package file...
#    did not generate dataset 1 kwargs
# adding Package:  NWT
#    NWT  package load...success
# loading oc package file...
# Adding freyberg.hds (unit=51) to the output list.
# adding Package:  OC
#    OC   package load...success
# loading wel package file...
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     1
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     2
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     3
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     4
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     5
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     6
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     7
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     8
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     9
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    10
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    11
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    12
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    13
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    14
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    15
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    16
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    17
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    18
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    19
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    20
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    21
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    22
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    23
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    24
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    25
# adding Package:  WEL
#    WEL  package load...success
# loading rch package file...
#    loading rech stress period   1...
#    loading rech stress period   2...
#    loading rech stress period   3...
#    loading rech stress period   4...
#    loading rech stress period   5...
#    loading rech stress period   6...
#    loading rech stress period   7...
#    loading rech stress period   8...
#    loading rech stress period   9...
#    loading rech stress period  10...
#    loading rech stress period  11...
#    loading rech stress period  12...
#    loading rech stress period  13...
#    loading rech stress period  14...
#    loading rech stress period  15...
#    loading rech stress period  16...
#    loading rech stress period  17...
#    loading rech stress period  18...
#    loading rech stress period  19...
#    loading rech stress period  20...
#    loading rech stress period  21...
#    loading rech stress period  22...
#    loading rech stress period  23...
#    loading rech stress period  24...
#    loading rech stress period  25...
# adding Package:  RCH
#    RCH  package load...success
# loading ghb package file...
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     1
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     2
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     3
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     4
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     5
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     6
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     7
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     8
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper     9
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    10
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    11
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    12
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    13
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    14
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    15
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    16
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    17
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    18
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    19
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    20
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    21
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    22
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    23
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    24
#    loading <class 'flopy.modflow.mfghb.ModflowGhb'> for kper    25
# adding Package:  GHB
#    GHB  package load...success
# loading sfr2 package file...
# Adding freyberg.sfr.out (unit=60) to the output list.
# adding Package:  SFR
#    SFR  package load...success
#    DATA(BINARY) file load...skipped
#       freyberg.cbc
#    DATA(BINARY) file load...skipped
#       freyberg.hds
#    DATA file load...skipped
#       freyberg.sfr.out
# Warning: external file unit 0 does not exist in ext_unit_dict.
#
#    The following 9 packages were successfully loaded.
#       freyberg.dis
#       freyberg.bas
#       freyberg.upw
#       freyberg.nwt
#       freyberg.oc
#       freyberg.wel
#       freyberg.rch
#       freyberg.ghb
#       freyberg.sfr
#    The following 1 packages were not loaded.
#       freyberg.list
# 2020-03-06 08:40:46.209648 finished: loading flopy model took: 0:00:00.066851
# 2020-03-06 08:40:46.209698 starting: updating model attributes
# 2020-03-06 08:40:46.209856 finished: updating model attributes took: 0:00:00.000158
# 2020-03-06 08:40:46.209918 WARNING: removing existing 'new_model_ws
#
# creating model workspace...
#    template_history
#
# changing model workspace...
#    template_history
# 2020-03-06 08:40:47.282262 starting: writing new modflow input files
#
# Writing packages:
#    Package:  DIS
# Util2d:delr: resetting 'how' to external
# Util2d:delc: resetting 'how' to external
# Util2d:model_top: resetting 'how' to external
# Util2d:botm_layer_0: resetting 'how' to external
# Util2d:botm_layer_1: resetting 'how' to external
# Util2d:botm_layer_2: resetting 'how' to external
#    Package:  BAS6
# Util2d:ibound_layer_0: resetting 'how' to external
# Util2d:ibound_layer_1: resetting 'how' to external
# Util2d:ibound_layer_2: resetting 'how' to external
# Util2d:strt_layer_0: resetting 'how' to external
# Util2d:strt_layer_1: resetting 'how' to external
# Util2d:strt_layer_2: resetting 'how' to external
#    Package:  UPW
# Util2d:hk: resetting 'how' to external
# Util2d:vk: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
# Util2d:sy: resetting 'how' to external
# Util2d:hk: resetting 'how' to external
# Util2d:vk: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
# Util2d:hk: resetting 'how' to external
# Util2d:vk: resetting 'how' to external
# Util2d:ss: resetting 'how' to external
#    Package:  NWT
#    Package:  OC
#    Package:  WEL
#    Package:  RCH
# Util2d:rech_1: resetting 'how' to external
# Util2d:rech_2: resetting 'how' to external
# Util2d:rech_3: resetting 'how' to external
# Util2d:rech_4: resetting 'how' to external
# Util2d:rech_5: resetting 'how' to external
# Util2d:rech_6: resetting 'how' to external
# Util2d:rech_7: resetting 'how' to external
# Util2d:rech_8: resetting 'how' to external
# Util2d:rech_9: resetting 'how' to external
# Util2d:rech_10: resetting 'how' to external
# Util2d:rech_11: resetting 'how' to external
# Util2d:rech_12: resetting 'how' to external
# Util2d:rech_13: resetting 'how' to external
# Util2d:rech_14: resetting 'how' to external
# Util2d:rech_15: resetting 'how' to external
# Util2d:rech_16: resetting 'how' to external
# Util2d:rech_17: resetting 'how' to external
# Util2d:rech_18: resetting 'how' to external
# Util2d:rech_19: resetting 'how' to external
# Util2d:rech_20: resetting 'how' to external
# Util2d:rech_21: resetting 'how' to external
# Util2d:rech_22: resetting 'how' to external
# Util2d:rech_23: resetting 'how' to external
# Util2d:rech_24: resetting 'how' to external
# Util2d:rech_25: resetting 'how' to external
#    Package:  GHB
#    Package:  SFR
#
# 2020-03-06 08:40:47.504769 finished: writing new modflow input files took: 0:00:00.222507
# 2020-03-06 08:40:47.505147 forward_run line:pyemu.os_utils.run('mfnwt freyberg.nam 1>freyberg.nam.stdout 2>freyberg.nam.stderr')
# 2020-03-06 08:40:47.505319 starting: setting up 'template_history/arr_org' dir
# 2020-03-06 08:40:47.505532 finished: setting up 'template_history/arr_org' dir took: 0:00:00.000213
# 2020-03-06 08:40:47.505701 starting: setting up 'template_history/arr_mlt' dir
# 2020-03-06 08:40:47.506039 finished: setting up 'template_history/arr_mlt' dir took: 0:00:00.000338
# 2020-03-06 08:40:47.506107 starting: setting up 'template_history/list_org' dir
# 2020-03-06 08:40:47.506360 finished: setting up 'template_history/list_org' dir took: 0:00:00.000253
# 2020-03-06 08:40:47.506511 starting: setting up 'template_history/list_mlt' dir
# 2020-03-06 08:40:47.506803 finished: setting up 'template_history/list_mlt' dir took: 0:00:00.000292
# 2020-03-06 08:40:47.506987 starting: processing temporal_list_props
# 2020-03-06 08:40:47.527100 finished: processing temporal_list_props took: 0:00:00.020113
# 2020-03-06 08:40:47.527187 starting: processing spatial_list_props
# 2020-03-06 08:40:47.841935 finished: processing spatial_list_props took: 0:00:00.314748
# 2020-03-06 08:40:48.219932 forward_run line:pyemu.helpers.apply_list_pars()
#
# 2020-03-06 08:40:48.235222 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.255821 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.275176 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.317300 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.336179 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.357794 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.396513 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.418356 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.438647 'extra' pak detected:extra.prsity
# 2020-03-06 08:40:48.594579 starting: writing grid tpl:hk3.dat_gr.tpl
# 2020-03-06 08:40:48.603585 finished: writing grid tpl:hk3.dat_gr.tpl took: 0:00:00.009006
# 2020-03-06 08:40:48.605466 starting: writing grid tpl:vka3.dat_gr.tpl
# 2020-03-06 08:40:48.613407 finished: writing grid tpl:vka3.dat_gr.tpl took: 0:00:00.007941
# 2020-03-06 08:40:48.615055 starting: writing grid tpl:ss3.dat_gr.tpl
# 2020-03-06 08:40:48.622010 finished: writing grid tpl:ss3.dat_gr.tpl took: 0:00:00.006955
# 2020-03-06 08:40:48.623581 starting: writing grid tpl:sy3.dat_gr.tpl
# 2020-03-06 08:40:48.630600 finished: writing grid tpl:sy3.dat_gr.tpl took: 0:00:00.007019
# 2020-03-06 08:40:48.632312 starting: writing grid tpl:prsity3.dat_gr.tpl
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3000019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3001019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3002019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3003019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3004019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3005019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3006019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007004
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007005
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007006
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3007019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008007
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3008019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3009019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3010019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011001
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011002
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011003
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011008
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011009
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011010
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011011
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011012
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011013
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011014
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011015
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011016
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011017
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011018
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3011019
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3012000
#   format(pname))
# /Users/jwhite/Dev/gw1876/activities_stpete/notebooks/pyemu/utils/helpers.py:3281: UserWarning: grid pname too long for pest:prsity3012001
#   format(pname))
# ...
# 2020-03-06 08:40:55.542581 pestcheck:12 characters long.
# 2020-03-06 08:40:55.542824 pestcheck:Line 2507 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.542939 pestcheck:once.
# 2020-03-06 08:40:55.542963 pestcheck:Line 2508 of file freyberg.pst: parameter name "prsity3001014" greater than
# 2020-03-06 08:40:55.542979 pestcheck:12 characters long.
# 2020-03-06 08:40:55.542994 pestcheck:Line 2508 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.543012 pestcheck:once.
# 2020-03-06 08:40:55.543026 pestcheck:Line 2509 of file freyberg.pst: parameter name "prsity3001015" greater than
# 2020-03-06 08:40:55.543041 pestcheck:12 characters long.
# 2020-03-06 08:40:55.543067 pestcheck:Line 2509 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.543085 pestcheck:once.
# 2020-03-06 08:40:55.543653 pestcheck:Line 2510 of file freyberg.pst: parameter name "prsity3001016" greater than
# 2020-03-06 08:40:55.543802 pestcheck:12 characters long.
# 2020-03-06 08:40:55.543825 pestcheck:Line 2510 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.543841 pestcheck:once.
# 2020-03-06 08:40:55.544043 pestcheck:Line 2511 of file freyberg.pst: parameter name "prsity3001017" greater than
# 2020-03-06 08:40:55.544065 pestcheck:12 characters long.
# 2020-03-06 08:40:55.544080 pestcheck:Line 2511 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.544099 pestcheck:once.
# 2020-03-06 08:40:55.544117 pestcheck:Line 2512 of file freyberg.pst: parameter name "prsity3001018" greater than
# 2020-03-06 08:40:55.544131 pestcheck:12 characters long.
# 2020-03-06 08:40:55.544146 pestcheck:Line 2512 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.544602 pestcheck:once.
# 2020-03-06 08:40:55.544637 pestcheck:Line 2513 of file freyberg.pst: parameter name "prsity3001019" greater than
# 2020-03-06 08:40:55.544655 pestcheck:12 characters long.
# 2020-03-06 08:40:55.544850 pestcheck:Line 2513 of file freyberg.pst: parameter name "prsity300101" used more than
# 2020-03-06 08:40:55.544895 pestcheck:once.
# 2020-03-06 08:40:55.545062 pestcheck:Line 2514 of file freyberg.pst: parameter name "prsity3002000" greater than
# 2020-03-06 08:40:55.545146 pestcheck:12 characters long.
# 2020-03-06 08:40:55.545167 pestcheck:Line 2515 of file freyberg.pst: parameter name "prsity3002001" greater than
# 2020-03-06 08:40:55.545183 pestcheck:12 characters long.
# 2020-03-06 08:40:55.545197 pestcheck:Line 2515 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.545526 pestcheck:once.
# 2020-03-06 08:40:55.545568 pestcheck:Line 2516 of file freyberg.pst: parameter name "prsity3002002" greater than
# 2020-03-06 08:40:55.545723 pestcheck:12 characters long.
# 2020-03-06 08:40:55.545746 pestcheck:Line 2516 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.545773 pestcheck:once.
# 2020-03-06 08:40:55.545792 pestcheck:Line 2517 of file freyberg.pst: parameter name "prsity3002003" greater than
# 2020-03-06 08:40:55.545807 pestcheck:12 characters long.
# 2020-03-06 08:40:55.545822 pestcheck:Line 2517 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.546133 pestcheck:once.
# 2020-03-06 08:40:55.546163 pestcheck:Line 2518 of file freyberg.pst: parameter name "prsity3002004" greater than
# 2020-03-06 08:40:55.546183 pestcheck:12 characters long.
# 2020-03-06 08:40:55.546199 pestcheck:Line 2518 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.546216 pestcheck:once.
# 2020-03-06 08:40:55.546234 pestcheck:Line 2519 of file freyberg.pst: parameter name "prsity3002005" greater than
# 2020-03-06 08:40:55.546248 pestcheck:12 characters long.
# 2020-03-06 08:40:55.546265 pestcheck:Line 2519 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.546283 pestcheck:once.
# 2020-03-06 08:40:55.546297 pestcheck:Line 2520 of file freyberg.pst: parameter name "prsity3002006" greater than
# 2020-03-06 08:40:55.546315 pestcheck:12 characters long.
# 2020-03-06 08:40:55.546331 pestcheck:Line 2520 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.546643 pestcheck:once.
# 2020-03-06 08:40:55.547118 pestcheck:Line 2521 of file freyberg.pst: parameter name "prsity3002007" greater than
# 2020-03-06 08:40:55.547206 pestcheck:12 characters long.
# 2020-03-06 08:40:55.547330 pestcheck:Line 2521 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.547513 pestcheck:once.
# 2020-03-06 08:40:55.547600 pestcheck:Line 2522 of file freyberg.pst: parameter name "prsity3002008" greater than
# 2020-03-06 08:40:55.547682 pestcheck:12 characters long.
# 2020-03-06 08:40:55.547761 pestcheck:Line 2522 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.547840 pestcheck:once.
# 2020-03-06 08:40:55.547918 pestcheck:Line 2523 of file freyberg.pst: parameter name "prsity3002009" greater than
# 2020-03-06 08:40:55.547995 pestcheck:12 characters long.
# 2020-03-06 08:40:55.548073 pestcheck:Line 2523 of file freyberg.pst: parameter name "prsity300200" used more than
# 2020-03-06 08:40:55.548151 pestcheck:once.
# 2020-03-06 08:40:55.548229 pestcheck:Line 2524 of file freyberg.pst: parameter name "prsity3002010" greater than
# 2020-03-06 08:40:55.548306 pestcheck:12 characters long.
# 2020-03-06 08:40:55.548383 pestcheck:Line 2525 of file freyberg.pst: parameter name "prsity3002011" greater than
# 2020-03-06 08:40:55.548587 pestcheck:12 characters long.
# 2020-03-06 08:40:55.548688 pestcheck:Line 2525 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.548775 pestcheck:once.
# 2020-03-06 08:40:55.548858 pestcheck:Line 2526 of file freyberg.pst: parameter name "prsity3002012" greater than
# 2020-03-06 08:40:55.548938 pestcheck:12 characters long.
# 2020-03-06 08:40:55.549018 pestcheck:Line 2526 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.549098 pestcheck:once.
# 2020-03-06 08:40:55.549180 pestcheck:Line 2527 of file freyberg.pst: parameter name "prsity3002013" greater than
# 2020-03-06 08:40:55.549259 pestcheck:12 characters long.
# 2020-03-06 08:40:55.549361 pestcheck:Line 2527 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.549486 pestcheck:once.
# 2020-03-06 08:40:55.549572 pestcheck:Line 2528 of file freyberg.pst: parameter name "prsity3002014" greater than
# 2020-03-06 08:40:55.549654 pestcheck:12 characters long.
# 2020-03-06 08:40:55.549736 pestcheck:Line 2528 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.549816 pestcheck:once.
# 2020-03-06 08:40:55.549895 pestcheck:Line 2529 of file freyberg.pst: parameter name "prsity3002015" greater than
# 2020-03-06 08:40:55.549974 pestcheck:12 characters long.
# 2020-03-06 08:40:55.550053 pestcheck:Line 2529 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.550132 pestcheck:once.
# 2020-03-06 08:40:55.550210 pestcheck:Line 2530 of file freyberg.pst: parameter name "prsity3002016" greater than
# 2020-03-06 08:40:55.550289 pestcheck:12 characters long.
# 2020-03-06 08:40:55.550367 pestcheck:Line 2530 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.550447 pestcheck:once.
# 2020-03-06 08:40:55.550610 pestcheck:Line 2531 of file freyberg.pst: parameter name "prsity3002017" greater than
# 2020-03-06 08:40:55.550696 pestcheck:12 characters long.
# 2020-03-06 08:40:55.550779 pestcheck:Line 2531 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.550821 pestcheck:once.
# 2020-03-06 08:40:55.550931 pestcheck:Line 2532 of file freyberg.pst: parameter name "prsity3002018" greater than
# 2020-03-06 08:40:55.551014 pestcheck:12 characters long.
# 2020-03-06 08:40:55.551094 pestcheck:Line 2532 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.551172 pestcheck:once.
# 2020-03-06 08:40:55.551249 pestcheck:Line 2533 of file freyberg.pst: parameter name "prsity3002019" greater than
# 2020-03-06 08:40:55.551380 pestcheck:12 characters long.
# 2020-03-06 08:40:55.551562 pestcheck:Line 2533 of file freyberg.pst: parameter name "prsity300201" used more than
# 2020-03-06 08:40:55.551649 pestcheck:once.
# 2020-03-06 08:40:55.551732 pestcheck:Line 2534 of file freyberg.pst: parameter name "prsity3003000" greater than
# 2020-03-06 08:40:55.551814 pestcheck:12 characters long.
# 2020-03-06 08:40:55.551895 pestcheck:Line 2535 of file freyberg.pst: parameter name "prsity3003001" greater than
# 2020-03-06 08:40:55.551974 pestcheck:12 characters long.
# 2020-03-06 08:40:55.552054 pestcheck:Line 2535 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.552199 pestcheck:once.
# 2020-03-06 08:40:55.552280 pestcheck:Line 2536 of file freyberg.pst: parameter name "prsity3003002" greater than
# 2020-03-06 08:40:55.552361 pestcheck:12 characters long.
# 2020-03-06 08:40:55.552442 pestcheck:Line 2536 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.552524 pestcheck:once.
# 2020-03-06 08:40:55.552705 pestcheck:Line 2537 of file freyberg.pst: parameter name "prsity3003003" greater than
# 2020-03-06 08:40:55.552831 pestcheck:12 characters long.
# 2020-03-06 08:40:55.552979 pestcheck:Line 2537 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.553064 pestcheck:once.
# 2020-03-06 08:40:55.553146 pestcheck:Line 2538 of file freyberg.pst: parameter name "prsity3003004" greater than
# 2020-03-06 08:40:55.553226 pestcheck:12 characters long.
# 2020-03-06 08:40:55.553304 pestcheck:Line 2538 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.553384 pestcheck:once.
# 2020-03-06 08:40:55.553465 pestcheck:Line 2539 of file freyberg.pst: parameter name "prsity3003005" greater than
# 2020-03-06 08:40:55.553611 pestcheck:12 characters long.
# 2020-03-06 08:40:55.553689 pestcheck:Line 2539 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.553934 pestcheck:once.
# 2020-03-06 08:40:55.553957 pestcheck:Line 2540 of file freyberg.pst: parameter name "prsity3003006" greater than
# 2020-03-06 08:40:55.553973 pestcheck:12 characters long.
# 2020-03-06 08:40:55.553989 pestcheck:Line 2540 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.554233 pestcheck:once.
# 2020-03-06 08:40:55.554265 pestcheck:Line 2541 of file freyberg.pst: parameter name "prsity3003007" greater than
# 2020-03-06 08:40:55.554282 pestcheck:12 characters long.
# 2020-03-06 08:40:55.554482 pestcheck:Line 2541 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.554539 pestcheck:once.
# 2020-03-06 08:40:55.554554 pestcheck:Line 2542 of file freyberg.pst: parameter name "prsity3003008" greater than
# 2020-03-06 08:40:55.554760 pestcheck:12 characters long.
# 2020-03-06 08:40:55.555014 pestcheck:Line 2542 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.555139 pestcheck:once.
# 2020-03-06 08:40:55.555225 pestcheck:Line 2543 of file freyberg.pst: parameter name "prsity3003009" greater than
# 2020-03-06 08:40:55.555304 pestcheck:12 characters long.
# 2020-03-06 08:40:55.555383 pestcheck:Line 2543 of file freyberg.pst: parameter name "prsity300300" used more than
# 2020-03-06 08:40:55.555462 pestcheck:once.
# 2020-03-06 08:40:55.555542 pestcheck:Line 2544 of file freyberg.pst: parameter name "prsity3003010" greater than
# 2020-03-06 08:40:55.555619 pestcheck:12 characters long.
# 2020-03-06 08:40:55.555724 pestcheck:Line 2545 of file freyberg.pst: parameter name "prsity3003011" greater than
# 2020-03-06 08:40:55.555944 pestcheck:12 characters long.
# 2020-03-06 08:40:55.556092 pestcheck:Line 2545 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.556179 pestcheck:once.
# 2020-03-06 08:40:55.556258 pestcheck:Line 2546 of file freyberg.pst: parameter name "prsity3003012" greater than
# 2020-03-06 08:40:55.556337 pestcheck:12 characters long.
# 2020-03-06 08:40:55.556415 pestcheck:Line 2546 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.556493 pestcheck:once.
# 2020-03-06 08:40:55.556572 pestcheck:Line 2547 of file freyberg.pst: parameter name "prsity3003013" greater than
# 2020-03-06 08:40:55.556651 pestcheck:12 characters long.
# 2020-03-06 08:40:55.556729 pestcheck:Line 2547 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.556806 pestcheck:once.
# 2020-03-06 08:40:55.556884 pestcheck:Line 2548 of file freyberg.pst: parameter name "prsity3003014" greater than
# 2020-03-06 08:40:55.556966 pestcheck:12 characters long.
# 2020-03-06 08:40:55.557150 pestcheck:Line 2548 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.557237 pestcheck:once.
# 2020-03-06 08:40:55.557319 pestcheck:Line 2549 of file freyberg.pst: parameter name "prsity3003015" greater than
# 2020-03-06 08:40:55.557398 pestcheck:12 characters long.
# 2020-03-06 08:40:55.557481 pestcheck:Line 2549 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.557561 pestcheck:once.
# 2020-03-06 08:40:55.557639 pestcheck:Line 2550 of file freyberg.pst: parameter name "prsity3003016" greater than
# 2020-03-06 08:40:55.557719 pestcheck:12 characters long.
# 2020-03-06 08:40:55.557797 pestcheck:Line 2550 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.557863 pestcheck:once.
# 2020-03-06 08:40:55.558066 pestcheck:Line 2551 of file freyberg.pst: parameter name "prsity3003017" greater than
# 2020-03-06 08:40:55.558155 pestcheck:12 characters long.
# 2020-03-06 08:40:55.558234 pestcheck:Line 2551 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.558313 pestcheck:once.
# 2020-03-06 08:40:55.558391 pestcheck:Line 2552 of file freyberg.pst: parameter name "prsity3003018" greater than
# 2020-03-06 08:40:55.558468 pestcheck:12 characters long.
# 2020-03-06 08:40:55.558545 pestcheck:Line 2552 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.558622 pestcheck:once.
# 2020-03-06 08:40:55.558698 pestcheck:Line 2553 of file freyberg.pst: parameter name "prsity3003019" greater than
# 2020-03-06 08:40:55.558778 pestcheck:12 characters long.
# 2020-03-06 08:40:55.558854 pestcheck:Line 2553 of file freyberg.pst: parameter name "prsity300301" used more than
# 2020-03-06 08:40:55.558932 pestcheck:once.
# 2020-03-06 08:40:55.559008 pestcheck:Line 2554 of file freyberg.pst: parameter name "prsity3004000" greater than
# 2020-03-06 08:40:55.559086 pestcheck:12 characters long.
# 2020-03-06 08:40:55.559163 pestcheck:Line 2555 of file freyberg.pst: parameter name "prsity3004001" greater than
# 2020-03-06 08:40:55.559239 pestcheck:12 characters long.
# 2020-03-06 08:40:55.559315 pestcheck:Line 2555 of file freyberg.pst: parameter name "prsity300400" used more than
# 2020-03-06 08:40:55.559391 pestcheck:once.
# 2020-03-06 08:40:55.559467 pestcheck:Line 2556 of file freyberg.pst: parameter name "prsity3004002" greater than
# 2020-03-06 08:40:55.559544 pestcheck:12 characters long.
# 2020-03-06 08:40:55.559621 pestcheck:Line 2556 of file freyberg.pst: parameter name "prsity300400" used more than
# 2020-03-06 08:40:55.559697 pestcheck:once.
# 2020-03-06 08:40:55.559774 pestcheck:Line 2557 of file freyberg.pst: parameter name "prsity3004003" greater than
# 2020-03-06 08:40:55.559851 pestcheck:12 characters long.
# 2020-03-06 08:40:55.560002 finished: running pestchek on freyberg.pst took: 0:00:00.083313
# 2020-03-06 08:40:55.560112 starting: saving intermediate _setup_<> dfs into template_history
# 2020-03-06 08:40:55.671978 finished: saving intermediate _setup_<> dfs into template_history took: 0:00:00.111866
# 2020-03-06 08:40:55.672055 all done

# %% [markdown]
# Take some time to inspect the `template_history` directory that was just created in the same directory where this notebook is running.  You should find a pest control file names `freyberg.pst`, heaps of PEST-style template and instruction files and a python script named `forward_run.py`.  Let's checkout this script:

# %%
[print(i.rstrip()) for i in open('template_history/forward_run.py','r').readlines()];
# Out:
# import os
# import multiprocessing as mp
# import numpy as np
# import pandas as pd
# import flopy
# import pyemu
# def main():
#
#     try:
#        os.remove('freyberg.list')
#     except Exception as e:
#        print('error removing tmp file:freyberg.list')
#     try:
#        os.remove('freyberg.hds')
#     except Exception as e:
#        print('error removing tmp file:freyberg.hds')
#     pyemu.helpers.apply_list_pars()
#
#     pyemu.helpers.apply_array_pars()
#
#     pyemu.os_utils.run('mfnwt freyberg.nam 1>freyberg.nam.stdout 2>freyberg.nam.stderr')
#     pyemu.gw_utils.apply_mflist_budget_obs('freyberg.list',flx_filename='flux.dat',vol_filename='vol.dat',start_datetime='12-31-2015')
#     pyemu.gw_utils.apply_hds_obs('freyberg.hds')
#     pyemu.gw_utils.apply_sfr_obs()
#
# if __name__ == '__main__':
#     mp.freeze_support()
#     main()

# %% [markdown]
# So that `pst_helper` instance wrote this python script - WAT?!  Each time one of the PEST++ tools "runs the model", it will call this script, which will handle the required pre-processing to construct MODFLOW input files, run MODFLOW, and post-process the MODFLOW output files into files that PEST can read (with the instruction files).

# %% [markdown]
# ### Investigating the `pst_helper` instance

# %% [markdown]
# The `pst_helper` instance contains the `pyemu.Pst` instance:

# %%
# so, pull out the `pyemu.Pst` instance which 
#contains all the input that ultimately goes in the PEST control %%file
pst = pst_helper.pst
pst.npar,pst.nobs
# Out:
# (11909, 6954)

# %% [markdown]
# ### Oh snap!

# %% [markdown]
# `pyemu` uses `pandas` data frame format for the parameter and observation data sections. This offers plenty of querying and bulk editing options.
#
# Let's stop for a moment to get a better feel for what just happened! Let's dig in..

# %%
# check out hydraulic conductivity parameters
pst.parameter_data.loc[pst.parameter_data.parnme.str.contains('hk'),:]
# Out:
#                       parnme partrans parchglim  parval1  parlbnd  parubnd  \
# const_hk6__cn  const_hk6__cn      log    factor      1.0     0.10     10.0
# const_hk7__cn  const_hk7__cn      log    factor      1.0     0.10     10.0
# const_hk8__cn  const_hk8__cn      log    factor      1.0     0.10     10.0
# hk000                  hk000      log    factor      1.0     0.01    100.0
# hk001                  hk001      log    factor      1.0     0.01    100.0
# ...                      ...      ...       ...      ...      ...      ...
# hk5039011          hk5039011      log    factor      1.0     0.01    100.0
# hk5039012          hk5039012      log    factor      1.0     0.01    100.0
# hk5039013          hk5039013      log    factor      1.0     0.01    100.0
# hk5039014          hk5039014      log    factor      1.0     0.01    100.0
# hk5039015          hk5039015      log    factor      1.0     0.01    100.0
#
#                 pargp  scale  offset  dercom
# const_hk6__cn  cn_hk6    1.0     0.0       1
# const_hk7__cn  cn_hk7    1.0     0.0       1
# const_hk8__cn  cn_hk8    1.0     0.0       1
# hk000          pp_hk0    1.0     0.0       1
# hk001          pp_hk0    1.0     0.0       1
# ...               ...    ...     ...     ...
# hk5039011      gr_hk5    1.0     0.0       1
# hk5039012      gr_hk5    1.0     0.0       1
# hk5039013      gr_hk5    1.0     0.0       1
# hk5039014      gr_hk5    1.0     0.0       1
# hk5039015      gr_hk5    1.0     0.0       1
#
# [2217 rows x 10 columns]

# %%
# what about observations? in particular, the sfr flow-out observations?
pst.observation_data.loc[pst.observation_data.obgnme.apply(lambda x: "flout" in x),:]
# Out:
#                                 obsnme    obsval  weight obgnme
# fo_gage_1_20160101  fo_gage_1_20160101   1195.50     1.0  flout
# fo_gage_1_20160201  fo_gage_1_20160201   1623.30     1.0  flout
# fo_gage_1_20160301  fo_gage_1_20160301   1921.40     1.0  flout
# fo_gage_1_20160401  fo_gage_1_20160401   2058.00     1.0  flout
# fo_gage_1_20160501  fo_gage_1_20160501   1969.40     1.0  flout
# ...                                ...       ...     ...    ...
# fo_tw_20170901          fo_tw_20170901   7643.09     1.0  flout
# fo_tw_20171001          fo_tw_20171001   6847.12     1.0  flout
# fo_tw_20171101          fo_tw_20171101   9623.62     1.0  flout
# fo_tw_20171201          fo_tw_20171201  15120.17     1.0  flout
# fo_tw_20180101          fo_tw_20180101  21998.73     1.0  flout
#
# [75 rows x 4 columns]

# %% [markdown]
# You can see we have flow-out `observations` (in the PEST sense) for "gage_1", tailwaters ("tw") and headwaters ("hw"). Let's give these observations more meaningful group names (the `obgnme` attribute)

# %%
obs = pst.observation_data
flout_obs = obs.loc[obs.obgnme.apply(lambda x: "flout" in x),"obsnme"]
obs.loc[flout_obs,"obgnme"] = flout_obs.apply(lambda x: "_".join(x.split('_')[:-1]))
obs.loc[flout_obs,"obgnme"].unique()
# Out:
# array(['fo_gage_1', 'fo_hw', 'fo_tw'], dtype=object)

# %% [markdown]
# ### Add time-series based observations
#
# We need to track specific head locations across all times for transient state observations that have been "measured".  To setup the tracking, we need to know where (lay-row-col) the observations are located

# %%
obs_locs = pd.read_csv(os.path.join("..","base_model_files","obs_loc.csv"))
#build obs names that correspond to the obsnme values in the control file
obs_locs.loc[:,"site"] = obs_locs.apply(lambda x: "trgw_{0:03d}_{1:03d}".format(x.row-1,x.col-1),axis=1)
kij_dict = {site:(2,r-1,c-1) for site,r,c in zip(obs_locs.site,obs_locs.row,obs_locs.col)}
obs_locs
# Out:
#     row  col          site
# 0     3   16  trgw_002_015
# 1     3   10  trgw_002_009
# 2     4    9  trgw_003_008
# 3    10    2  trgw_009_001
# 4    14   11  trgw_013_010
# 5    16   17  trgw_015_016
# 6    22   11  trgw_021_010
# 7    23   16  trgw_022_015
# 8    25    5  trgw_024_004
# 9    27    7  trgw_026_006
# 10   30   16  trgw_029_015
# 11   34    8  trgw_033_007
# 12   35   11  trgw_034_010

# %%
kij_dict
# Out:
# {'trgw_002_015': (2, 2, 15),
#  'trgw_002_009': (2, 2, 9),
#  'trgw_003_008': (2, 3, 8),
#  'trgw_009_001': (2, 9, 1),
#  'trgw_013_010': (2, 13, 10),
#  'trgw_015_016': (2, 15, 16),
#  'trgw_021_010': (2, 21, 10),
#  'trgw_022_015': (2, 22, 15),
#  'trgw_024_004': (2, 24, 4),
#  'trgw_026_006': (2, 26, 6),
#  'trgw_029_015': (2, 29, 15),
#  'trgw_033_007': (2, 33, 7),
#  'trgw_034_010': (2, 34, 10)}

# %% [markdown]
# We can use a `pyemu` groundwater utility to setup the transient groundwater level monitoring for us.  We need that location dictionary from above and the name of the binary file to process (the MODFLOW "head save" file).  Important: only run this code block once!!!

# %%
binary_file = os.path.join(pst_helper.m.model_ws,nam_file.replace(".nam",".hds"))
frun_line,tr_hds_df = pyemu.gw_utils.setup_hds_timeseries(binary_file,kij_dict=kij_dict,include_path=True,model=pst_helper.m)
pst_helper.frun_post_lines.append(frun_line)
print(frun_line.strip());
# Out:
# writing config file to template_history/freyberg.hds_timeseries.config
# writing instruction file to template_history/freyberg.hds_timeseries.processed.ins
# pyemu.gw_utils.apply_hds_timeseries('freyberg.hds_timeseries.config',None)

# %% [markdown]
# You can see that the `frun_line` is in fact a valid line of python code - we added it to the `pst_helper` container for post-processing forward-run script lines:

# %%
[print(i.strip()) for i in pst_helper.frun_post_lines];
# Out:
# pyemu.gw_utils.apply_mflist_budget_obs('freyberg.list',flx_filename='flux.dat',vol_filename='vol.dat',start_datetime='12-31-2015')
# pyemu.gw_utils.apply_hds_obs('freyberg.hds')
# pyemu.gw_utils.apply_sfr_obs()
# pyemu.gw_utils.apply_hds_timeseries('freyberg.hds_timeseries.config',None)

# %% [markdown]
# We can also see the `tr_hds_df` is a dataframe of the simulated groundwater levels extracted from the head save file,
# with other PEST-relevant columns. The `obsval` is the extracted simulated groundwater levels, the `obsnme` is the PEST observation names (encoded as `<site>_<datetime>`).  And since we added the row and col to the site names, we now have the metadata nessecary to understand where in space and in time these observations are - sweet as!

# %%
tr_hds_df.head()
# Out:
#                           obsval  weight obgnme
# trgw_002_009_20160101  34.577084     0.0   trgw
# trgw_002_009_20160201  34.675034     0.0   trgw
# trgw_002_009_20160301  34.771618     0.0   trgw
# trgw_002_009_20160401  34.842045     0.0   trgw
# trgw_002_009_20160501  34.853950     0.0   trgw

# %% [markdown]
# Now we need to add these new (PEST) "obseravtions" to the control file.  To do that, we need the instruction file (which as also written by that nice setup routine - so thoughtful!)

# %%
[f for f in os.listdir(pst_helper.m.model_ws) if f.endswith(".ins")]
# Out:
# ['freyberg.hds.dat.ins',
#  'freyberg.hds_timeseries.processed.ins',
#  'vol.dat.ins',
#  'freyberg.sfr.out.processed.ins',
#  'flux.dat.ins']

# %% [markdown]
# We will use the `pyemu.Pst.add_observations` method for this.  Important: only run this block once!!!

# %%
df = pst_helper.pst.add_observations(os.path.join(pst_helper.m.model_ws,
                nam_file.replace(".nam",".hds_timeseries.processed.ins")),pst_path=".")
obs = pst_helper.pst.observation_data
obs.loc[df.index,"obgnme"] = df.index.map(lambda x: "_".join(x.split("_")[:-1]))
obs.loc[df.index,"weight"] = 1.0
obs.loc[df.index,"obgnme"].unique()
# Out:
# array(['trgw_002_015', 'trgw_002_009', 'trgw_003_008', 'trgw_009_001',
#        'trgw_013_010', 'trgw_015_016', 'trgw_021_010', 'trgw_022_015',
#        'trgw_024_004', 'trgw_026_006', 'trgw_029_015', 'trgw_033_007',
#        'trgw_034_010'], dtype=object)

# %% [markdown]
# There are our new transient groundwater level observation groups.

# %% [markdown]
# ### Add modpath input files, instruction files and calls

# %% [markdown]
# First copy over all the MODPATH-related files from the base directory identified in the `b_d` variable.   We will track a single particle for forecast purposes

# %%
mp_files = [f for f in os.listdir(b_d) if "mp" in f or "location" in f]
[shutil.copy2(os.path.join(b_d,f),os.path.join(pst_helper.new_model_ws,f)) for f in mp_files]
# Out:
# ['template_history/freyberg.mpenpt',
#  'template_history/mp6',
#  'template_history/mp_ibound_1.ref',
#  'template_history/mp_ibound_2.ref',
#  'template_history/mp_ibound_3.ref',
#  'template_history/freyberg.mppthln',
#  'template_history/freyberg.locations',
#  'template_history/freyberg.mpsim',
#  'template_history/freyberg.mplist',
#  'template_history/freyberg.mpbas',
#  'template_history/freyberg.mpnam']

# %% [markdown]
# The following `frun_post_lines` property adds statements at the end of the `forward_run.py` script. In this case, it runs MODPATH using `mp6`.  We will also identify any additional temporary files that the forward run script will attempt to remove at the start of a run.

# %%
#pst_helper.frun_post_lines.append("os.system('mp6 freyberg.mpsim >mp6.stdout')")
pst_helper.frun_post_lines.append("pyemu.os_utils.run('mp6 freyberg.mpsim >mp6.stdout')")
pst_helper.tmp_files.append("freyberg.mpenpt")  # placed at top of `forward_run.py`

# %% [markdown]
# Since we have added new commands for the forward run process, we need to re-write the `forward_run.py` script:

# %%
pst_helper.write_forward_run()

# %% [markdown]
# Let's see how it changed:

# %%
[print(i.rstrip()) for i in open('template_history/forward_run.py','r').readlines()];
# Out:
# import os
# import multiprocessing as mp
# import numpy as np
# import pandas as pd
# import flopy
# import pyemu
# def main():
#
#     try:
#        os.remove('freyberg.list')
#     except Exception as e:
#        print('error removing tmp file:freyberg.list')
#     try:
#        os.remove('freyberg.hds')
#     except Exception as e:
#        print('error removing tmp file:freyberg.hds')
#     try:
#        os.remove('freyberg.mpenpt')
#     except Exception as e:
#        print('error removing tmp file:freyberg.mpenpt')
#     pyemu.helpers.apply_list_pars()
#
#     pyemu.helpers.apply_array_pars()
#
#     pyemu.os_utils.run('mfnwt freyberg.nam 1>freyberg.nam.stdout 2>freyberg.nam.stderr')
#     pyemu.gw_utils.apply_mflist_budget_obs('freyberg.list',flx_filename='flux.dat',vol_filename='vol.dat',start_datetime='12-31-2015')
#     pyemu.gw_utils.apply_hds_obs('freyberg.hds')
#     pyemu.gw_utils.apply_sfr_obs()
#     pyemu.gw_utils.apply_hds_timeseries('freyberg.hds_timeseries.config',None)
#
#     pyemu.os_utils.run('mp6 freyberg.mpsim >mp6.stdout')
#
# if __name__ == '__main__':
#     mp.freeze_support()
#     main()

# %% [markdown]
# Sweet!  now we have added the MODPATH bits to this script.

# %% [markdown]
# Now we need to create and add an instruction file and related observations for MODPATH - we will track a single particle released need the western groundwater divide and use both its travel time and particle status as "observations" in the control file (well, actually, we will use these two quantities as forecasts!)

# %%
# write a really simple instruction file to read the MODPATH end point file
out_file = "freyberg.mpenpt"
ins_file = out_file + ".ins"
with open(os.path.join(pst_helper.new_model_ws,ins_file),'w') as f:
    f.write("pif ~\n")
    f.write("l7 w w w !part_status! w w !part_time!\n")

# %% [markdown]
# Just like before, we need to add these "observations" to our pest control file:

# %%
df = pst_helper.pst.add_observations(os.path.join(pst_helper.new_model_ws,ins_file),
                                     os.path.join(pst_helper.new_model_ws,out_file),
                                     pst_path=".")

# %% [markdown]
# We also need to copy the original prsity arrays to the `arr_org` dir for use in the multiplier parameterization scheme

# %%
for k in range(m.nlay):
    np.savetxt(os.path.join(pst_helper.new_model_ws,"arr_org","prsity_layer_{0}.ref".format(k+1)),
               np.zeros((m.nrow,m.ncol))+0.0005,fmt="%15.6E")

# %% [markdown]
# ### Final bits and bobs
# We need to set some realistic parameter bounds and account for expected (but stochastic) values:

# %%
par = pst.parameter_data  # we inspected this guy earlier
tag_dict = {"hk":[0.1,10.0],"vka":[0.1,10],"strt":[0.95,1.05],"pr":[0.8,1.2],"rech":[0.8,1.2],
                "wf":[0.8,1.2],"welflux":[0.8,1.2]}
for t,[l,u] in tag_dict.items():
    t_pars = par.loc[par.parnme.apply(lambda x: t in x ),"parnme"]
    par.loc[t_pars,"parubnd"] = u
    par.loc[t_pars,"parlbnd"] = l

# %% [markdown]
# given the combinations of multipliers, we need to set a hard upper bound on `sy` and `prsity` since they have physical upper limit (note: seperate to bounds handled explicitly by pest).  This is how you set bounds on the actual model input arrays that MODFLOW will use:

# %%
arr_csv = os.path.join(pst_helper.new_model_ws,"arr_pars.csv")
df = pd.read_csv(arr_csv,index_col=0)
df.head()
# Out:
#                      org_file                mlt_file            model_file  \
# 0      arr_org/hk_Layer_1.ref      arr_mlt/hk0.dat_pp      ./hk_Layer_1.ref
# 1            arr_org/vka1.ref     arr_mlt/vka0.dat_pp            ./vka1.ref
# 2      arr_org/ss_Layer_1.ref      arr_mlt/ss0.dat_pp      ./ss_Layer_1.ref
# 3      arr_org/sy_Layer_1.ref      arr_mlt/sy0.dat_pp      ./sy_Layer_1.ref
# 4  arr_org/prsity_layer_1.ref  arr_mlt/prsity0.dat_pp  ./prsity_layer_1.ref
#
#    layer suffix   prefix attr_name tpl_file              fac_file  \
# 0      0    _pp      hk0        hk      NaN  pp_k0_general_zn.fac
# 1      0    _pp     vka0       vka      NaN  pp_k0_general_zn.fac
# 2      0    _pp      ss0        ss      NaN  pp_k0_general_zn.fac
# 3      0    _pp      sy0        sy      NaN  pp_k0_general_zn.fac
# 4      0    _pp  prsity0    prsity      NaN  pp_k0_general_zn.fac
#
#          pp_file
# 0      hk0pp.dat
# 1     vka0pp.dat
# 2      ss0pp.dat
# 3      sy0pp.dat
# 4  prsity0pp.dat

# %%
sy_pr = df.model_file.apply(lambda x: "sy" in x or "pr" in x)
df.loc[:,"upper_bound"] = np.NaN
df.loc[sy_pr,"upper_bound"] = 0.4
#rch = df.model_file.apply(lambda x: "rech" in x)
#df.loc[rch,"upper_bound"] = 1000.0
df.to_csv(arr_csv)

# %%
# table can also be written to a .tex file (report-ready!)
df = pst.write_par_summary_table(filename="none").sort_index()
df.loc[df.index.map(lambda x: "rech" in x),:]
# Out:
#                 type transform  count initial value upper bound lower bound  \
# cn_rech10  cn_rech10       log      1             0    0.113943   -0.154902
# cn_rech11  cn_rech11       log      1             0    0.113943   -0.154902
# cn_rech12  cn_rech12       log      1             0    0.113943   -0.154902
# cn_rech13  cn_rech13       log      1             0    0.113943   -0.154902
# cn_rech14  cn_rech14       log      1             0    0.113943   -0.154902
# cn_rech15  cn_rech15       log      1             0    0.113943   -0.154902
# cn_rech16  cn_rech16       log      1             0    0.113943   -0.154902
# cn_rech17  cn_rech17       log      1             0    0.113943   -0.154902
# cn_rech18  cn_rech18       log      1             0    0.113943   -0.154902
# cn_rech19  cn_rech19       log      1             0    0.113943   -0.154902
# cn_rech2    cn_rech2       log      1             0    0.113943   -0.154902
# cn_rech20  cn_rech20       log      1             0    0.113943   -0.154902
# cn_rech21  cn_rech21       log      1             0    0.113943   -0.154902
# cn_rech22  cn_rech22       log      1             0    0.113943   -0.154902
# cn_rech23  cn_rech23       log      1             0    0.113943   -0.154902
# cn_rech24  cn_rech24       log      1             0    0.113943   -0.154902
# cn_rech25  cn_rech25       log      1             0    0.113943   -0.154902
# cn_rech26  cn_rech26       log      1             0    0.113943   -0.154902
# cn_rech3    cn_rech3       log      1             0    0.113943   -0.154902
# cn_rech4    cn_rech4       log      1             0    0.113943   -0.154902
# cn_rech5    cn_rech5       log      1             0    0.113943   -0.154902
# cn_rech6    cn_rech6       log      1             0    0.113943   -0.154902
# cn_rech7    cn_rech7       log      1             0    0.113943   -0.154902
# cn_rech8    cn_rech8       log      1             0    0.113943   -0.154902
# cn_rech9    cn_rech9       log      1             0    0.113943   -0.154902
# gr_rech1    gr_rech1       log    706             0    0.113943   -0.154902
# pp_rech0    pp_rech0       log     32             0    0.113943   -0.154902
#
#           standard deviation
# cn_rech10          0.0672113
# cn_rech11          0.0672113
# cn_rech12          0.0672113
# cn_rech13          0.0672113
# cn_rech14          0.0672113
# cn_rech15          0.0672113
# cn_rech16          0.0672113
# cn_rech17          0.0672113
# cn_rech18          0.0672113
# cn_rech19          0.0672113
# cn_rech2           0.0672113
# cn_rech20          0.0672113
# cn_rech21          0.0672113
# cn_rech22          0.0672113
# cn_rech23          0.0672113
# cn_rech24          0.0672113
# cn_rech25          0.0672113
# cn_rech26          0.0672113
# cn_rech3           0.0672113
# cn_rech4           0.0672113
# cn_rech5           0.0672113
# cn_rech6           0.0672113
# cn_rech7           0.0672113
# cn_rech8           0.0672113
# cn_rech9           0.0672113
# gr_rech1           0.0672113
# pp_rech0           0.0672113

# %%
pst.write_obs_summary_table(filename="none").head()
# Out:
#                group                value  non-zero weight  zero weight  \
# flaqx          flaqx  -1011.88 to -8.1901               75            0
# fo_gage_1  fo_gage_1      415.63 to  2058               25            0
# fo_hw          fo_hw   3486.67 to 13331.8               25            0
# fo_tw          fo_tw   6730.11 to 33303.2               25            0
# hds              hds   33.5579 to 34.8769             6354            0
#
#           weight standard deviation            percent error
# flaqx          1                  1     0.0988256 to 12.2099
# fo_gage_1      1                  1    0.0485909 to 0.240599
# fo_hw          1                  1  0.00750088 to 0.0286807
# fo_tw          1                  1  0.00300271 to 0.0148586
# hds            1                  1       2.86723 to 2.97993

# %% [markdown]
# Let's run the process once (`noptmax=0`) to make sure its all plumbed up.  Pro-tip: you can use any of the `pestpp-###` binaries/executables to run `noptmax=0`

# %%
pst.control_data.noptmax = 0
pst.write(os.path.join(pst_helper.new_model_ws,"freyberg.pst"))
pyemu.os_utils.run("pestpp-glm freyberg.pst",cwd=pst_helper.new_model_ws)
# Out:
# noptmax:0, npar_adj:11909, nnz_obs:7281

# %%
pst = pyemu.Pst(os.path.join(pst_helper.m.model_ws,"freyberg.pst"))

# %% [markdown]
# Now if we look in the `template_history` dir, you should see a "freyberg.rec" file - the PESTPP-IES run record file

# %%
[print(i.rstrip()) for i in open('template_history/freyberg.rec','r').readlines()[-20:]];
# Out:
#   Contribution to phi from observation group    "fo_gage_1" : 0.000100000
#   Contribution to phi from observation group        "fo_hw" : 0.000500000
#   Contribution to phi from observation group        "fo_tw" : 0.0118000
#   Contribution to phi from observation group          "hds" : 3.91451e-09
#   Contribution to phi from observation group "trgw_002_015" : 2.50000e-11
#   Contribution to phi from observation group "trgw_002_009" : 1.60000e-11
#   Contribution to phi from observation group "trgw_003_008" : 0.00000
#   Contribution to phi from observation group "trgw_009_001" : 1.80000e-11
#   Contribution to phi from observation group "trgw_013_010" : 5.00000e-11
#   Contribution to phi from observation group "trgw_015_016" : 4.10000e-11
#   Contribution to phi from observation group "trgw_021_010" : 3.20000e-11
#   Contribution to phi from observation group "trgw_022_015" : 1.60000e-11
#   Contribution to phi from observation group "trgw_024_004" : 0.00000
#   Contribution to phi from observation group "trgw_026_006" : 0.00000
#   Contribution to phi from observation group "trgw_029_015" : 0.00000
#   Contribution to phi from observation group "trgw_033_007" : 3.80000e-11
#   Contribution to phi from observation group "trgw_034_010" : 5.00000e-11
#
#
# Number of forward model runs performed during optimiztion: 1

# %% [markdown]
# Now let's take it up a notch. We need to generate the prior parameter covariance matrix and stochastic realizations. In the author's opinion, this one of the hardest tasks for us groundwater people and also one of the most important.  The `PstFromFlopyModel` class was originally created to just to help with this task. So let's use it!  The `pst_helper` has some default geostatistical structures stored with it.  These structures use a range that is proportional to the model grid spacing and have a sill of 1.0 - using this sill is very important - it lets us later use the parameter bounds to scale the resulting covariance matrix blocks by the uncertainty implied by the bounds.

# %%
pst_helper.grid_geostruct.plot()

# %%
if pst_helper.pst.npar < 35000: #if you have more than about 35K pars, the cov matrix becomes hard to handle
    # build out the full cov matrix and write it to a compressed binary file
    cov = pst_helper.build_prior(fmt="coo",filename=os.path.join(pst_helper.new_model_ws,"prior_cov.jcb"))
    # mask for plotting
    cov = np.ma.masked_where(cov.x==0,cov.x)
    try:
        fig = plt.figure(figsize=(10,10))
        ax = plt.subplot(111)
        ax.imshow(cov)
        plt.show()
    except:
        pass
# Out:
# 2020-03-06 08:41:01.480659 starting: building prior covariance matrix
# //miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# //miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 2020-03-06 08:41:04.836489 saving prior covariance matrix to file template_history/prior_cov.jcb
# 2020-03-06 08:41:07.072417 finished: building prior covariance matrix took: 0:00:05.591758

# %% [markdown]
# That's it: a full geostatistically-correlated block-diagonal covariance matrix.  Let's take a moment to soak that up!

# %% [markdown]
# ### now we can make a draw from the prior parameter covariance matrix to form a prior parameter ensemble
#
# The `pst_helper.draw()` method is very efficient, especially when the number of parameters is >35K.  It avoids forming the full cov matrix and instead operates block by block and, for grid-scale parameters, switches to 2-D spectral simulation.

# %%
pe = pst_helper.draw(300)
# Out:
# 2020-03-06 08:41:12.515954 starting: drawing realizations
# building diagonal cov
# processing  name:grid_geostruct,nugget:0.0,structures:
# name:var1,contribution:1.0,a:2500.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['gr_hk3']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_vka3']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_ss3']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_sy3']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_prsity3']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_hk4']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_vka4']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_ss4']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_sy4']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_prsity4']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_hk5']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_vka5']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_ss5']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_sy5']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_prsity5']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# working on pargroups ['gr_rech1']
# build cov matrix
# done
# getting diag var cov 706
# scaling full cov by diag var cov
# processing  name:pp_geostruct,nugget:0.0,structures:
# name:var1,contribution:1.0,a:1000.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['pp_hk0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_prsity0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_rech0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_ss0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_sy0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_vka0']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_hk1']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_prsity1']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_ss1']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_sy1']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_vka1']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_hk2']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_prsity2']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_ss2']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_sy2']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['pp_vka2']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# processing  name:spatial_list_geostruct,nugget:0.0,structures:
# name:var1,contribution:1.0,a:2500.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['welflux_k02']
# build cov matrix
# done
# getting diag var cov 6
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_k00']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_k01']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_k02']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# processing  name:temporal_list_geostruct,nugget:0.0,structures:
# name:var1,contribution:1.0,a:180.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['welflux']
# build cov matrix
# done
# getting diag var cov 25
# scaling full cov by diag var cov
# adding remaining parameters to diagonal
# 2020-03-06 08:41:17.531129 finished: drawing realizations took: 0:00:05.015175

# %% [markdown]
# You can see that parameters are treated in parameter group (`pargp`) blocks for this ensemble generation.

# %% [markdown]
# Always a good idea to inspect the parameter ensemble for reasonableness! Can do via slicing and dicing...

# %%
pe.iloc[-10:-5,:10]
# Out:
# return type uncaught, losing Ensemble type, returing DataFrame
#      hk3000000  hk3000001  hk3000002  hk3000003  hk3000004  hk3000005  \
# 290   0.476214   0.376057   0.349991   0.515296   0.567776   1.020566
# 291   1.001443   1.041973   1.156869   1.362478   1.487089   1.074363
# 292   0.593851   1.372580   0.709896   0.588610   0.484248   0.344925
# 293   0.392114   0.520459   1.253681   0.852501   0.935400   1.332853
# 294   0.818262   0.798813   1.970848   1.739221   1.201896   1.644289
#
#      hk3000006  hk3000007  hk3000008  hk3000009
# 290   1.104491   1.693272   1.359198   1.486217
# 291   1.347594   1.615994   1.605436   0.997036
# 292   0.379344   0.251470   0.219745   0.216666
# 293   2.094414   1.412227   3.040790   1.380420
# 294   1.940320   1.054923   0.589309   0.602276

# %% [markdown]
# Let's look at parameters by groups

# %%
par = pst_helper.pst.parameter_data
pyemu.plot_utils.ensemble_helper(pe,plot_cols=par.groupby("pargp").groups,bins=20)
plt.show()

# %% [markdown]
# Thoughts? Do these look reasonable? We see log-normal distributions for log-transformed parameters, e.g., hk... looking good!

# %% [markdown]
# Now we need to enforce parameter bounds and save this ensemble for later

# %%
pe.enforce()  # always a good idea!
pe.to_binary(os.path.join(pst_helper.new_model_ws,"prior.jcb"))
pst_helper.pst.write(os.path.join(pst_helper.m.model_ws,nam_file.replace(".nam",".pst")))
# Out:
# return type uncaught, losing Ensemble type, returing DataFrame
# noptmax:0, npar_adj:11909, nnz_obs:7281

# %% [markdown]
# ### Set forecast names - just a few for FOSM later

# %%
obs = pst_helper.pst.observation_data
dts = pd.to_datetime(pst_helper.m.start_datetime) + pd.to_timedelta(np.cumsum(pst_helper.m.dis.perlen.array),unit='d')
dts_str = list(dts.map(lambda x: x.strftime("%Y%m%d")).values)
dry_dt = dts_str[dry_kper]
print(dry_dt)
swgw_forecasts = obs.loc[obs.obsnme.apply(lambda x: "fa" in x and ("hw" in x or "tw" in x) and dry_dt in x),"obsnme"].tolist()
#print(swgw_forecasts)
hds_fore_name = "hds_00_{0:03d}_{1:03d}_{2:03d}".format(int(pst_helper.m.nrow/3),int(pst_helper.m.ncol/10)
                                                       ,dry_kper)
print(hds_fore_name)
hds_forecasts = obs.loc[obs.obsnme.apply(lambda x: hds_fore_name in x),"obsnme"].tolist()
forecasts = swgw_forecasts
forecasts.extend(hds_forecasts)
forecasts.append("part_time")
forecasts.append("part_status")
pst_helper.pst.pestpp_options["forecasts"] = forecasts
forecasts
# Out:
# 20171001
# hds_00_013_002_021
# ['fa_hw_20171001',
#  'fa_tw_20171001',
#  'hds_00_013_002_021',
#  'part_time',
#  'part_status']

# %%
pst_helper.pst.write(os.path.join(pst_helper.m.model_ws,nam_file.replace(".nam",".pst")))
# Out:
# noptmax:0, npar_adj:11909, nnz_obs:7281

# %% [markdown]
# ### "This is not the python command you are looking for"

# %%
prep_deps.prep_forecasts()
# Out:
#                                 obsnme      obsval  weight  obgnme  extra
# obsnme
# fa_hw_20171001          fa_hw_20171001 -201.743300     1.0   flaqx    NaN
# fa_tw_20171001          fa_tw_20171001 -160.992300     1.0   flaqx    NaN
# hds_00_013_002_021  hds_00_013_002_021   34.604008     1.0     hds    NaN
# part_time                    part_time  719.869200     1.0  obgnme    NaN
# part_status                part_status    2.000000     1.0  obgnme    NaN
#                         obsval
# obsnme
# fa_hw_20170913     -207.803646
# fa_tw_20170913      -12.324782
# hds_00_013_002_621   35.433281
# part_time           547.242400
# part_status           2.000000
#                                 obsnme      obsval  weight  obgnme  extra
# obsnme
# fa_hw_20171001          fa_hw_20171001 -207.803646     1.0   flaqx    NaN
# fa_tw_20171001          fa_tw_20171001  -12.324782     1.0   flaqx    NaN
# hds_00_013_002_021  hds_00_013_002_021   35.433281     1.0     hds    NaN
# part_time                    part_time  547.242400     1.0  obgnme    NaN
# part_status                part_status    2.000000     1.0  obgnme    NaN
# noptmax:0, npar_adj:11909, nnz_obs:7281

# %%
pyemu.os_utils.run("pestpp-ies {0}".format(nam_file.replace(".nam",".pst")),cwd=pst_helper.m.model_ws)

# %%
pst = pyemu.Pst(os.path.join(pst_helper.m.model_ws,"freyberg.pst"))
pst.res.loc[pst.forecast_names,:]
# Out:
#                                   name   group    measured    modelled  \
# name
# fa_hw_20171001          fa_hw_20171001   flaqx -201.743300 -201.744700
# fa_tw_20171001          fa_tw_20171001   flaqx -160.992300 -160.992400
# hds_00_013_002_021  hds_00_013_002_021     hds   34.604008   34.604008
# part_time                    part_time  obgnme  719.869200  719.869900
# part_status                part_status  obgnme    2.000000    2.000000
#
#                         residual  weight
# name
# fa_hw_20171001      1.400000e-03     1.0
# fa_tw_20171001      1.000000e-04     1.0
# hds_00_013_002_021  5.273648e-11     1.0
# part_time          -7.000000e-04     1.0
# part_status         0.000000e+00     1.0

# %%
lst = flopy.utils.MfListBudget(os.path.join(pst_helper.m.model_ws,nam_file.replace(".nam",".list")))
df = lst.get_dataframes(diff=True,start_datetime=pst_helper.m.start_datetime)[0]
df.plot(kind="bar",figsize=(30,30), grid=True,subplots=True)
plt.show()

# %% [markdown]
# ### Demystifying the multiplier parameter process!

# %%
def run_and_plot_hk(real):
    # replace the par values in the control file
    pst.parameter_data.loc[:,"parval1"] = pe.loc[real,pst.par_names]
    # save the updated control file
    pst.write(os.path.join(pst_helper.new_model_ws,"test.pst"))
    # run a single model run to generate the multipliers and inputs
    pyemu.os_utils.run("pestpp-ies.exe test.pst",cwd=pst_helper.new_model_ws)

    # load the arrays
    base_arr = np.log10(np.loadtxt(os.path.join(pst_helper.new_model_ws,"arr_org","hk_Layer_1.ref")))
    pp_arr = np.log10(np.loadtxt(os.path.join(pst_helper.new_model_ws,"arr_mlt","hk0.dat_pp")))
    gr_arr = np.log10(np.loadtxt(os.path.join(pst_helper.new_model_ws,"arr_mlt","hk3.dat_gr")))
    cn_arr = np.log10(np.loadtxt(os.path.join(pst_helper.new_model_ws,"arr_mlt","hk6.dat_cn")))
    in_arr = np.log10(np.loadtxt(os.path.join(pst_helper.new_model_ws,"hk_Layer_1.ref")))
    arrs = [base_arr,cn_arr,pp_arr,gr_arr,in_arr]
    
    labels = ["log10 base","log10 constant","log10 pilot points","log10 grid","log10 resulting input"]
    # mask with ibound
    ib = m.bas6.ibound[0].array
    for i,arr in enumerate(arrs):
        arr[ib==0] = np.NaN
    
    fig,axes = plt.subplots(1,5,figsize=(20,5))
    
    # work out the multiplier min and max
    vmin1 = min([np.nanmin(a) for a in arrs[1:-1]])
    vmax1 = max([np.nanmax(a) for a in arrs[1:-1]])
    
    # plot each array
    for i,(ax,arr,label) in enumerate(zip(axes,arrs,labels)):
        if i not in [0,len(arrs)-1]:  
            cb = ax.imshow(arr,vmin=vmin1,vmax=vmax1)
        else:
            cb = ax.imshow(arr)
        ax.set_title(label)
        ax.set_yticks([])
        ax.set_xticks([])
        plt.colorbar(cb,ax=ax)
    plt.tight_layout()
    plt.show()

# %%
run_and_plot_hk(5)
# Out:
# noptmax:0, npar_adj:11909, nnz_obs:7281

# %%
run_and_plot_hk(10)
# Out:
# noptmax:0, npar_adj:11909, nnz_obs:7281
